# %% [markdown]
# # Reference

# %%
from piper import piper
from piper.verbs import *
from piper.defaults import *
from piper.styler import *
# Out:
# piper version 0.0.7, last run: Friday, 26 February 2021 15:07:03

# %% [markdown]
# ## helper functions

# %%
def clean_merge(df, headers, fillna=0):
    '''
    '''

    logger.info('Clearing null values...')
    df.fillna(fillna, inplace=True)

    logger.info('Setting integer value data types...')
    for x in headers:
        if df[x].dtype != 'object':
            df[x] = pd.to_numeric(df[x], downcast='integer')

    return df

# %% [markdown]
# # Merging (joining) two tables

# %%
# https://youtu.be/_5EhKDCm9VY

# %%
headers = ['account', 'type', 'balance']
headers2 = [x + '2' for x in headers]

f = 'inputs/data merge testing.xlsx'
sheet_name = 'Example #1'

df1 = pd.read_excel(f, sheet_name=sheet_name, usecols='A:C')
df2 = pd.read_excel(f, sheet_name=sheet_name, usecols='F:H', header=0, names=headers2)

# %% [markdown]
# ## Inner join

# %%
merge_df = pd.merge(df1, df2, how='inner', left_on=['account'], right_on=['account2'])
head(merge_df).style.hide_index()
# Out:
# 13 rows, 6 columns
# <style  type="text/css" >
# </style><table id="T_14162_" ><thead>    <tr>        <th class="col_heading level0 col0" >account</th>        <th class="col_heading level0 col1" >type</th>        <th class="col_heading level0 col2" >balance</th>        <th class="col_heading level0 col3" >account2</th>        <th class="col_heading level0 col4" >type2</th>        <th class="col_heading level0 col5" >balance2</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_14162_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_14162_row0_col1" class="data row0 col1" >checking</td>
#                         <td id="T_14162_row0_col2" class="data row0 col2" >87</td>
#                         <td id="T_14162_row0_col3" class="data row0 col3" >1</td>
#                         <td id="T_14162_row0_col4" class="data row0 col4" >checking</td>
#                         <td id="T_14162_row0_col5" class="data row0 col5" >87</td>
#             </tr>
#             <tr>
#                                 <td id="T_14162_row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_14162_row1_col1" class="data row1 col1" >checking</td>
#                         <td id="T_14162_row1_col2" class="data row1 col2" >36</td>
#                         <td id="T_14162_row1_col3" class="data row1 col3" >2</td>
#                         <td id="T_14162_row1_col4" class="data row1 col4" >savings</td>
#                         <td id="T_14162_row1_col5" class="data row1 col5" >36</td>
#             </tr>
#             <tr>
#                                 <td id="T_14162_row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_14162_row2_col1" class="data row2 col1" >checking</td>
#                         <td id="T_14162_row2_col2" class="data row2 col2" >82</td>
#                         <td id="T_14162_row2_col3" class="data row2 col3" >3</td>
#                         <td id="T_14162_row2_col4" class="data row2 col4" >checking</td>
#                         <td id="T_14162_row2_col5" class="data row2 col5" >82</td>
#             </tr>
#             <tr>
#                                 <td id="T_14162_row3_col0" class="data row3 col0" >4</td>
#                         <td id="T_14162_row3_col1" class="data row3 col1" >checking</td>
#                         <td id="T_14162_row3_col2" class="data row3 col2" >76</td>
#                         <td id="T_14162_row3_col3" class="data row3 col3" >4</td>
#                         <td id="T_14162_row3_col4" class="data row3 col4" >checking</td>
#                         <td id="T_14162_row3_col5" class="data row3 col5" >76</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Outer join

# %%
merge_df = (pd.merge(df1, df2, how='outer',
                    left_on=['account'], right_on=['account2'])
              .sort_values(by='account', ascending=False))
head(merge_df, 4)
# Out:
# 14 rows, 6 columns
#     account     type  balance  account2     type2  balance2
# 12       13  savings       20      13.0  checking      54.0
# 13       13  savings       20      13.0   savings      20.0
# 11       12  savings       31      12.0   savings      33.0
# 10       11  savings       16      11.0   savings      30.0

# %% [markdown]
# # Styling examples

# %% [markdown]
# ### Highlight (including null) values

# %%
(head(merge_df, 5).style
                  .apply(highlight_values, criteria=['savings'],
                         subset=['type', 'type2'])
                  .apply(highlight_values, criteria=['checking'],
                         subset=['type', 'type2'], color='blue')
                  .apply(highlight_values, criteria=[20, 54],
                         subset=['balance', 'balance2'], color='purple')
                  .apply(highlight_values, criteria=[20, 54],
                         subset=['balance', 'balance2'], type='background', color='orange')
                  .hide_index()
                  .highlight_null(null_color='lightgreen')
)
# Out:
# 14 rows, 6 columns
# <style  type="text/css" >
# #T_78da1_row0_col1,#T_78da1_row1_col1,#T_78da1_row1_col4,#T_78da1_row2_col1,#T_78da1_row2_col4,#T_78da1_row3_col1,#T_78da1_row3_col4{
#             color:  red;
#         }#T_78da1_row0_col2,#T_78da1_row0_col5,#T_78da1_row1_col2,#T_78da1_row1_col5,#T_78da1_row4_col2{
#             color:  purple;
#             background-color:  orange;
#         }#T_78da1_row0_col4,#T_78da1_row4_col1{
#             color:  blue;
#         }#T_78da1_row4_col3,#T_78da1_row4_col4,#T_78da1_row4_col5{
#             background-color:  lightgreen;
#         }</style><table id="T_78da1_" ><thead>    <tr>        <th class="col_heading level0 col0" >account</th>        <th class="col_heading level0 col1" >type</th>        <th class="col_heading level0 col2" >balance</th>        <th class="col_heading level0 col3" >account2</th>        <th class="col_heading level0 col4" >type2</th>        <th class="col_heading level0 col5" >balance2</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_78da1_row0_col0" class="data row0 col0" >13</td>
#                         <td id="T_78da1_row0_col1" class="data row0 col1" >savings</td>
#                         <td id="T_78da1_row0_col2" class="data row0 col2" >20</td>
#                         <td id="T_78da1_row0_col3" class="data row0 col3" >13.000000</td>
#                         <td id="T_78da1_row0_col4" class="data row0 col4" >checking</td>
#                         <td id="T_78da1_row0_col5" class="data row0 col5" >54.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_78da1_row1_col0" class="data row1 col0" >13</td>
#                         <td id="T_78da1_row1_col1" class="data row1 col1" >savings</td>
#                         <td id="T_78da1_row1_col2" class="data row1 col2" >20</td>
#                         <td id="T_78da1_row1_col3" class="data row1 col3" >13.000000</td>
#                         <td id="T_78da1_row1_col4" class="data row1 col4" >savings</td>
#                         <td id="T_78da1_row1_col5" class="data row1 col5" >20.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_78da1_row2_col0" class="data row2 col0" >12</td>
#                         <td id="T_78da1_row2_col1" class="data row2 col1" >savings</td>
#                         <td id="T_78da1_row2_col2" class="data row2 col2" >31</td>
#                         <td id="T_78da1_row2_col3" class="data row2 col3" >12.000000</td>
#                         <td id="T_78da1_row2_col4" class="data row2 col4" >savings</td>
#                         <td id="T_78da1_row2_col5" class="data row2 col5" >33.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_78da1_row3_col0" class="data row3 col0" >11</td>
#                         <td id="T_78da1_row3_col1" class="data row3 col1" >savings</td>
#                         <td id="T_78da1_row3_col2" class="data row3 col2" >16</td>
#                         <td id="T_78da1_row3_col3" class="data row3 col3" >11.000000</td>
#                         <td id="T_78da1_row3_col4" class="data row3 col4" >savings</td>
#                         <td id="T_78da1_row3_col5" class="data row3 col5" >30.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_78da1_row4_col0" class="data row4 col0" >10</td>
#                         <td id="T_78da1_row4_col1" class="data row4 col1" >checking</td>
#                         <td id="T_78da1_row4_col2" class="data row4 col2" >54</td>
#                         <td id="T_78da1_row4_col3" class="data row4 col3" >nan</td>
#                         <td id="T_78da1_row4_col4" class="data row4 col4" >nan</td>
#                         <td id="T_78da1_row4_col5" class="data row4 col5" >nan</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Highlight (True/False) values

# %%
merge_df['account2 is null'] = merge_df['account2'].isna()
merge_df = clean_merge(merge_df, headers+headers2)
(head(merge_df, 5).style
                  .apply(highlight_values, criteria=[False],
                         subset=['account2 is null', 'balance2', 'type2'],
                         color='red')
                  .apply(highlight_values, criteria=[False],
                         subset=['account2 is null', 'balance2', 'type2'],
                         type='background', color='yellow')
)
# Out:
# Clearing null values...
# Setting integer value data types...
# 14 rows, 7 columns
# <style  type="text/css" >
# #T_8a0b5_row0_col6,#T_8a0b5_row1_col6,#T_8a0b5_row2_col6,#T_8a0b5_row3_col6,#T_8a0b5_row4_col4,#T_8a0b5_row4_col5{
#             color:  red;
#             background-color:  yellow;
#         }</style><table id="T_8a0b5_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >account</th>        <th class="col_heading level0 col1" >type</th>        <th class="col_heading level0 col2" >balance</th>        <th class="col_heading level0 col3" >account2</th>        <th class="col_heading level0 col4" >type2</th>        <th class="col_heading level0 col5" >balance2</th>        <th class="col_heading level0 col6" >account2 is null</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8a0b5_level0_row0" class="row_heading level0 row0" >12</th>
#                         <td id="T_8a0b5_row0_col0" class="data row0 col0" >13</td>
#                         <td id="T_8a0b5_row0_col1" class="data row0 col1" >savings</td>
#                         <td id="T_8a0b5_row0_col2" class="data row0 col2" >20</td>
#                         <td id="T_8a0b5_row0_col3" class="data row0 col3" >13</td>
#                         <td id="T_8a0b5_row0_col4" class="data row0 col4" >checking</td>
#                         <td id="T_8a0b5_row0_col5" class="data row0 col5" >54</td>
#                         <td id="T_8a0b5_row0_col6" class="data row0 col6" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_8a0b5_level0_row1" class="row_heading level0 row1" >13</th>
#                         <td id="T_8a0b5_row1_col0" class="data row1 col0" >13</td>
#                         <td id="T_8a0b5_row1_col1" class="data row1 col1" >savings</td>
#                         <td id="T_8a0b5_row1_col2" class="data row1 col2" >20</td>
#                         <td id="T_8a0b5_row1_col3" class="data row1 col3" >13</td>
#                         <td id="T_8a0b5_row1_col4" class="data row1 col4" >savings</td>
#                         <td id="T_8a0b5_row1_col5" class="data row1 col5" >20</td>
#                         <td id="T_8a0b5_row1_col6" class="data row1 col6" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_8a0b5_level0_row2" class="row_heading level0 row2" >11</th>
#                         <td id="T_8a0b5_row2_col0" class="data row2 col0" >12</td>
#                         <td id="T_8a0b5_row2_col1" class="data row2 col1" >savings</td>
#                         <td id="T_8a0b5_row2_col2" class="data row2 col2" >31</td>
#                         <td id="T_8a0b5_row2_col3" class="data row2 col3" >12</td>
#                         <td id="T_8a0b5_row2_col4" class="data row2 col4" >savings</td>
#                         <td id="T_8a0b5_row2_col5" class="data row2 col5" >33</td>
#                         <td id="T_8a0b5_row2_col6" class="data row2 col6" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_8a0b5_level0_row3" class="row_heading level0 row3" >10</th>
#                         <td id="T_8a0b5_row3_col0" class="data row3 col0" >11</td>
#                         <td id="T_8a0b5_row3_col1" class="data row3 col1" >savings</td>
#                         <td id="T_8a0b5_row3_col2" class="data row3 col2" >16</td>
#                         <td id="T_8a0b5_row3_col3" class="data row3 col3" >11</td>
#                         <td id="T_8a0b5_row3_col4" class="data row3 col4" >savings</td>
#                         <td id="T_8a0b5_row3_col5" class="data row3 col5" >30</td>
#                         <td id="T_8a0b5_row3_col6" class="data row3 col6" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_8a0b5_level0_row4" class="row_heading level0 row4" >9</th>
#                         <td id="T_8a0b5_row4_col0" class="data row4 col0" >10</td>
#                         <td id="T_8a0b5_row4_col1" class="data row4 col1" >checking</td>
#                         <td id="T_8a0b5_row4_col2" class="data row4 col2" >54</td>
#                         <td id="T_8a0b5_row4_col3" class="data row4 col3" >0</td>
#                         <td id="T_8a0b5_row4_col4" class="data row4 col4" >0</td>
#                         <td id="T_8a0b5_row4_col5" class="data row4 col5" >0</td>
#                         <td id="T_8a0b5_row4_col6" class="data row4 col6" >True</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Background gradient values

# %%
(merge_df.pipe(pd.DataFrame.sort_values, by='balance2', ascending=False)
                           .style                     
                           .background_gradient(subset='balance2', cmap='coolwarm')
                           .apply(highlight_values, criteria=[33, 76], subset=['balance'],
                                  color='yellow')
                           .apply(highlight_values, criteria=[33, 76], subset=['balance'],
                                  type='background', color='blue')
                           .apply(highlight_values, criteria=[4, 13], subset=['account'],
                                  color='red')
                           .apply(highlight_values, criteria=[4, 13], subset=['account'],
                                  type='background', color='lightpink')
                           .hide_index()
)
# Out:
# <style  type="text/css" >
# #T_647a7_row0_col5{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_647a7_row1_col5{
#             background-color:  #c83836;
#             color:  #f1f1f1;
#         }#T_647a7_row2_col2,#T_647a7_row3_col2,#T_647a7_row8_col2{
#             color:  yellow;
#             background-color:  blue;
#         }#T_647a7_row2_col5,#T_647a7_row3_col5{
#             background-color:  #de614d;
#             color:  #000000;
#         }#T_647a7_row3_col0,#T_647a7_row4_col0,#T_647a7_row11_col0{
#             color:  red;
#             background-color:  lightpink;
#         }#T_647a7_row4_col5{
#             background-color:  #f4c6af;
#             color:  #000000;
#         }#T_647a7_row5_col5{
#             background-color:  #dbdcde;
#             color:  #000000;
#         }#T_647a7_row6_col5{
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }#T_647a7_row7_col5,#T_647a7_row8_col5{
#             background-color:  #bad0f8;
#             color:  #000000;
#         }#T_647a7_row9_col5{
#             background-color:  #aec9fc;
#             color:  #000000;
#         }#T_647a7_row10_col5{
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }#T_647a7_row11_col5{
#             background-color:  #85a8fc;
#             color:  #000000;
#         }#T_647a7_row12_col5{
#             background-color:  #7da0f9;
#             color:  #000000;
#         }#T_647a7_row13_col5{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_647a7_" ><thead>    <tr>        <th class="col_heading level0 col0" >account</th>        <th class="col_heading level0 col1" >type</th>        <th class="col_heading level0 col2" >balance</th>        <th class="col_heading level0 col3" >account2</th>        <th class="col_heading level0 col4" >type2</th>        <th class="col_heading level0 col5" >balance2</th>        <th class="col_heading level0 col6" >account2 is null</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_647a7_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_647a7_row0_col1" class="data row0 col1" >checking</td>
#                         <td id="T_647a7_row0_col2" class="data row0 col2" >87</td>
#                         <td id="T_647a7_row0_col3" class="data row0 col3" >1</td>
#                         <td id="T_647a7_row0_col4" class="data row0 col4" >checking</td>
#                         <td id="T_647a7_row0_col5" class="data row0 col5" >87</td>
#                         <td id="T_647a7_row0_col6" class="data row0 col6" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_647a7_row1_col0" class="data row1 col0" >3</td>
#                         <td id="T_647a7_row1_col1" class="data row1 col1" >checking</td>
#                         <td id="T_647a7_row1_col2" class="data row1 col2" >82</td>
#                         <td id="T_647a7_row1_col3" class="data row1 col3" >3</td>
#                         <td id="T_647a7_row1_col4" class="data row1 col4" >checking</td>
#                         <td id="T_647a7_row1_col5" class="data row1 col5" >82</td>
#                         <td id="T_647a7_row1_col6" class="data row1 col6" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_647a7_row2_col0" class="data row2 col0" >8</td>
#                         <td id="T_647a7_row2_col1" class="data row2 col1" >checking</td>
#                         <td id="T_647a7_row2_col2" class="data row2 col2" >33</td>
#                         <td id="T_647a7_row2_col3" class="data row2 col3" >8</td>
#                         <td id="T_647a7_row2_col4" class="data row2 col4" >savings</td>
#                         <td id="T_647a7_row2_col5" class="data row2 col5" >76</td>
#                         <td id="T_647a7_row2_col6" class="data row2 col6" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_647a7_row3_col0" class="data row3 col0" >4</td>
#                         <td id="T_647a7_row3_col1" class="data row3 col1" >checking</td>
#                         <td id="T_647a7_row3_col2" class="data row3 col2" >76</td>
#                         <td id="T_647a7_row3_col3" class="data row3 col3" >4</td>
#                         <td id="T_647a7_row3_col4" class="data row3 col4" >checking</td>
#                         <td id="T_647a7_row3_col5" class="data row3 col5" >76</td>
#                         <td id="T_647a7_row3_col6" class="data row3 col6" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_647a7_row4_col0" class="data row4 col0" >13</td>
#                         <td id="T_647a7_row4_col1" class="data row4 col1" >savings</td>
#                         <td id="T_647a7_row4_col2" class="data row4 col2" >20</td>
#                         <td id="T_647a7_row4_col3" class="data row4 col3" >13</td>
#                         <td id="T_647a7_row4_col4" class="data row4 col4" >checking</td>
#                         <td id="T_647a7_row4_col5" class="data row4 col5" >54</td>
#                         <td id="T_647a7_row4_col6" class="data row4 col6" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_647a7_row5_col0" class="data row5 col0" >6</td>
#                         <td id="T_647a7_row5_col1" class="data row5 col1" >checking</td>
#                         <td id="T_647a7_row5_col2" class="data row5 col2" >27</td>
#                         <td id="T_647a7_row5_col3" class="data row5 col3" >6</td>
#                         <td id="T_647a7_row5_col4" class="data row5 col4" >checking</td>
#                         <td id="T_647a7_row5_col5" class="data row5 col5" >43</td>
#                         <td id="T_647a7_row5_col6" class="data row5 col6" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_647a7_row6_col0" class="data row6 col0" >2</td>
#                         <td id="T_647a7_row6_col1" class="data row6 col1" >checking</td>
#                         <td id="T_647a7_row6_col2" class="data row6 col2" >36</td>
#                         <td id="T_647a7_row6_col3" class="data row6 col3" >2</td>
#                         <td id="T_647a7_row6_col4" class="data row6 col4" >savings</td>
#                         <td id="T_647a7_row6_col5" class="data row6 col5" >36</td>
#                         <td id="T_647a7_row6_col6" class="data row6 col6" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_647a7_row7_col0" class="data row7 col0" >12</td>
#                         <td id="T_647a7_row7_col1" class="data row7 col1" >savings</td>
#                         <td id="T_647a7_row7_col2" class="data row7 col2" >31</td>
#                         <td id="T_647a7_row7_col3" class="data row7 col3" >12</td>
#                         <td id="T_647a7_row7_col4" class="data row7 col4" >savings</td>
#                         <td id="T_647a7_row7_col5" class="data row7 col5" >33</td>
#                         <td id="T_647a7_row7_col6" class="data row7 col6" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_647a7_row8_col0" class="data row8 col0" >5</td>
#                         <td id="T_647a7_row8_col1" class="data row8 col1" >savings</td>
#                         <td id="T_647a7_row8_col2" class="data row8 col2" >76</td>
#                         <td id="T_647a7_row8_col3" class="data row8 col3" >5</td>
#                         <td id="T_647a7_row8_col4" class="data row8 col4" >checking</td>
#                         <td id="T_647a7_row8_col5" class="data row8 col5" >33</td>
#                         <td id="T_647a7_row8_col6" class="data row8 col6" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_647a7_row9_col0" class="data row9 col0" >11</td>
#                         <td id="T_647a7_row9_col1" class="data row9 col1" >savings</td>
#                         <td id="T_647a7_row9_col2" class="data row9 col2" >16</td>

# %% [markdown]
# ### heatmap

# %%
xx = merge_df.style.background_gradient(cmap='viridis').hide_index()
display(xx)
xx.to_excel('outputs/test4.xlsx', index=False)
# Out:
# <style  type="text/css" >
# #T_85e60_row0_col0,#T_85e60_row0_col3,#T_85e60_row1_col0,#T_85e60_row1_col3,#T_85e60_row13_col2,#T_85e60_row13_col5{
#             background-color:  #fde725;
#             color:  #000000;
#         }#T_85e60_row0_col2,#T_85e60_row1_col2{
#             background-color:  #481668;
#             color:  #f1f1f1;
#         }#T_85e60_row0_col5{
#             background-color:  #26ad81;
#             color:  #000000;
#         }#T_85e60_row1_col5{
#             background-color:  #3e4c8a;
#             color:  #f1f1f1;
#         }#T_85e60_row2_col0{
#             background-color:  #c8e020;
#             color:  #000000;
#         }#T_85e60_row2_col2{
#             background-color:  #3f4788;
#             color:  #f1f1f1;
#         }#T_85e60_row2_col3{
#             background-color:  #cde11d;
#             color:  #000000;
#         }#T_85e60_row2_col5,#T_85e60_row9_col5{
#             background-color:  #2c738e;
#             color:  #f1f1f1;
#         }#T_85e60_row3_col0{
#             background-color:  #90d743;
#             color:  #000000;
#         }#T_85e60_row3_col2,#T_85e60_row4_col3,#T_85e60_row4_col5,#T_85e60_row13_col0{
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }#T_85e60_row3_col3,#T_85e60_row9_col2,#T_85e60_row10_col2{
#             background-color:  #98d83e;
#             color:  #000000;
#         }#T_85e60_row3_col5{
#             background-color:  #2f6b8e;
#             color:  #f1f1f1;
#         }#T_85e60_row4_col0{
#             background-color:  #5ec962;
#             color:  #000000;
#         }#T_85e60_row4_col2,#T_85e60_row7_col3{
#             background-color:  #1f998a;
#             color:  #000000;
#         }#T_85e60_row5_col0{
#             background-color:  #35b779;
#             color:  #000000;
#         }#T_85e60_row5_col2{
#             background-color:  #460b5e;
#             color:  #f1f1f1;
#         }#T_85e60_row5_col3{
#             background-color:  #40bd72;
#             color:  #000000;
#         }#T_85e60_row5_col5{
#             background-color:  #404588;
#             color:  #f1f1f1;
#         }#T_85e60_row6_col0{
#             background-color:  #20a486;
#             color:  #000000;
#         }#T_85e60_row6_col2{
#             background-color:  #3c4f8a;
#             color:  #f1f1f1;
#         }#T_85e60_row6_col3{
#             background-color:  #25ac82;
#             color:  #000000;
#         }#T_85e60_row6_col5,#T_85e60_row10_col5{
#             background-color:  #aadc32;
#             color:  #000000;
#         }#T_85e60_row7_col0{
#             background-color:  #21918c;
#             color:  #000000;
#         }#T_85e60_row7_col2{
#             background-color:  #2d708e;
#             color:  #f1f1f1;
#         }#T_85e60_row7_col5{
#             background-color:  #33628d;
#             color:  #f1f1f1;
#         }#T_85e60_row8_col0{
#             background-color:  #287c8e;
#             color:  #000000;
#         }#T_85e60_row8_col2,#T_85e60_row12_col3{
#             background-color:  #453581;
#             color:  #f1f1f1;
#         }#T_85e60_row8_col3{
#             background-color:  #24878e;
#             color:  #000000;
#         }#T_85e60_row8_col5{
#             background-color:  #218f8d;
#             color:  #000000;
#         }#T_85e60_row9_col0{
#             background-color:  #31688e;
#             color:  #f1f1f1;
#         }#T_85e60_row9_col3{
#             background-color:  #2b748e;
#             color:  #f1f1f1;
#         }#T_85e60_row10_col0{
#             background-color:  #3b528b;
#             color:  #f1f1f1;
#         }#T_85e60_row10_col3{
#             background-color:  #34618d;
#             color:  #f1f1f1;
#         }#T_85e60_row11_col0{
#             background-color:  #443983;
#             color:  #f1f1f1;
#         }#T_85e60_row11_col2{
#             background-color:  #d0e11c;
#             color:  #000000;
#         }#T_85e60_row11_col3{
#             background-color:  #3d4d8a;
#             color:  #f1f1f1;
#         }#T_85e60_row11_col5{
#             background-color:  #dae319;
#             color:  #000000;
#         }#T_85e60_row12_col0{
#             background-color:  #481f70;
#             color:  #f1f1f1;
#         }#T_85e60_row12_col2{
#             background-color:  #375b8d;
#             color:  #f1f1f1;
#         }#T_85e60_row12_col5{
#             background-color:  #297b8e;
#             color:  #000000;
#         }#T_85e60_row13_col3{
#             background-color:  #481c6e;
#             color:  #f1f1f1;
#         }</style><table id="T_85e60_" ><thead>    <tr>        <th class="col_heading level0 col0" >account</th>        <th class="col_heading level0 col1" >type</th>        <th class="col_heading level0 col2" >balance</th>        <th class="col_heading level0 col3" >account2</th>        <th class="col_heading level0 col4" >type2</th>        <th class="col_heading level0 col5" >balance2</th>        <th class="col_heading level0 col6" >account2 is null</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_85e60_row0_col0" class="data row0 col0" >13</td>
#                         <td id="T_85e60_row0_col1" class="data row0 col1" >savings</td>
#                         <td id="T_85e60_row0_col2" class="data row0 col2" >20</td>
#                         <td id="T_85e60_row0_col3" class="data row0 col3" >13</td>
#                         <td id="T_85e60_row0_col4" class="data row0 col4" >checking</td>
#                         <td id="T_85e60_row0_col5" class="data row0 col5" >54</td>
#                         <td id="T_85e60_row0_col6" class="data row0 col6" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_85e60_row1_col0" class="data row1 col0" >13</td>
#                         <td id="T_85e60_row1_col1" class="data row1 col1" >savings</td>
#                         <td id="T_85e60_row1_col2" class="data row1 col2" >20</td>
#                         <td id="T_85e60_row1_col3" class="data row1 col3" >13</td>
#                         <td id="T_85e60_row1_col4" class="data row1 col4" >savings</td>
#                         <td id="T_85e60_row1_col5" class="data row1 col5" >20</td>
#                         <td id="T_85e60_row1_col6" class="data row1 col6" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_85e60_row2_col0" class="data row2 col0" >12</td>
#                         <td id="T_85e60_row2_col1" class="data row2 col1" >savings</td>
#                         <td id="T_85e60_row2_col2" class="data row2 col2" >31</td>
#                         <td id="T_85e60_row2_col3" class="data row2 col3" >12</td>
#                         <td id="T_85e60_row2_col4" class="data row2 col4" >savings</td>
#                         <td id="T_85e60_row2_col5" class="data row2 col5" >33</td>
#                         <td id="T_85e60_row2_col6" class="data row2 col6" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_85e60_row3_col0" class="data row3 col0" >11</td>
#                         <td id="T_85e60_row3_col1" class="data row3 col1" >savings</td>
#                         <td id="T_85e60_row3_col2" class="data row3 col2" >16</td>
#                         <td id="T_85e60_row3_col3" class="data row3 col3" >11</td>
#                         <td id="T_85e60_row3_col4" class="data row3 col4" >savings</td>
#                         <td id="T_85e60_row3_col5" class="data row3 col5" >30</td>
#                         <td id="T_85e60_row3_col6" class="data row3 col6" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_85e60_row4_col0" class="data row4 col0" >10</td>
#                         <td id="T_85e60_row4_col1" class="data row4 col1" >checking</td>
#                         <td id="T_85e60_row4_col2" class="data row4 col2" >54</td>
#                         <td id="T_85e60_row4_col3" class="data row4 col3" >0</td>
#                         <td id="T_85e60_row4_col4" class="data row4 col4" >0</td>
#                         <td id="T_85e60_row4_col5" class="data row4 col5" >0</td>
#                         <td id="T_85e60_row4_col6" class="data row4 col6" >True</td>
#             </tr

# %% [markdown]
# ### Highlight max/min values

# %%
(df2.sort_values(by='balance2', ascending=True).style
    .apply(highlight_max, subset='type2', color='orange') 
    .apply(highlight_max, subset='type2', type='background', color='black') 
    .apply(highlight_min, subset='balance2', color='orange')  
    .apply(highlight_min, subset='balance2', type='background', color='grey') 
    .hide_index()
)
# Out:
# <style  type="text/css" >
# #T_a4e98_row0_col2{
#             color:  orange;
#             background-color:  grey;
#         }#T_a4e98_row1_col1,#T_a4e98_row3_col1,#T_a4e98_row5_col1,#T_a4e98_row6_col1,#T_a4e98_row10_col1{
#             color:  orange;
#             background-color:  black;
#         }</style><table id="T_a4e98_" ><thead>    <tr>        <th class="col_heading level0 col0" >account2</th>        <th class="col_heading level0 col1" >type2</th>        <th class="col_heading level0 col2" >balance2</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_a4e98_row0_col0" class="data row0 col0" >9</td>
#                         <td id="T_a4e98_row0_col1" class="data row0 col1" >checking</td>
#                         <td id="T_a4e98_row0_col2" class="data row0 col2" >18</td>
#             </tr>
#             <tr>
#                                 <td id="T_a4e98_row1_col0" class="data row1 col0" >13</td>
#                         <td id="T_a4e98_row1_col1" class="data row1 col1" >savings</td>
#                         <td id="T_a4e98_row1_col2" class="data row1 col2" >20</td>
#             </tr>
#             <tr>
#                                 <td id="T_a4e98_row2_col0" class="data row2 col0" >7</td>
#                         <td id="T_a4e98_row2_col1" class="data row2 col1" >checking</td>
#                         <td id="T_a4e98_row2_col2" class="data row2 col2" >27</td>
#             </tr>
#             <tr>
#                                 <td id="T_a4e98_row3_col0" class="data row3 col0" >11</td>
#                         <td id="T_a4e98_row3_col1" class="data row3 col1" >savings</td>
#                         <td id="T_a4e98_row3_col2" class="data row3 col2" >30</td>
#             </tr>
#             <tr>
#                                 <td id="T_a4e98_row4_col0" class="data row4 col0" >5</td>
#                         <td id="T_a4e98_row4_col1" class="data row4 col1" >checking</td>
#                         <td id="T_a4e98_row4_col2" class="data row4 col2" >33</td>
#             </tr>
#             <tr>
#                                 <td id="T_a4e98_row5_col0" class="data row5 col0" >12</td>
#                         <td id="T_a4e98_row5_col1" class="data row5 col1" >savings</td>
#                         <td id="T_a4e98_row5_col2" class="data row5 col2" >33</td>
#             </tr>
#             <tr>
#                                 <td id="T_a4e98_row6_col0" class="data row6 col0" >2</td>
#                         <td id="T_a4e98_row6_col1" class="data row6 col1" >savings</td>
#                         <td id="T_a4e98_row6_col2" class="data row6 col2" >36</td>
#             </tr>
#             <tr>
#                                 <td id="T_a4e98_row7_col0" class="data row7 col0" >6</td>
#                         <td id="T_a4e98_row7_col1" class="data row7 col1" >checking</td>
#                         <td id="T_a4e98_row7_col2" class="data row7 col2" >43</td>
#             </tr>
#             <tr>
#                                 <td id="T_a4e98_row8_col0" class="data row8 col0" >13</td>
#                         <td id="T_a4e98_row8_col1" class="data row8 col1" >checking</td>
#                         <td id="T_a4e98_row8_col2" class="data row8 col2" >54</td>
#             </tr>
#             <tr>
#                                 <td id="T_a4e98_row9_col0" class="data row9 col0" >4</td>
#                         <td id="T_a4e98_row9_col1" class="data row9 col1" >checking</td>
#                         <td id="T_a4e98_row9_col2" class="data row9 col2" >76</td>
#             </tr>
#             <tr>
#                                 <td id="T_a4e98_row10_col0" class="data row10 col0" >8</td>
#                         <td id="T_a4e98_row10_col1" class="data row10 col1" >savings</td>
#                         <td id="T_a4e98_row10_col2" class="data row10 col2" >76</td>
#             </tr>
#             <tr>
#                                 <td id="T_a4e98_row11_col0" class="data row11 col0" >3</td>
#                         <td id="T_a4e98_row11_col1" class="data row11 col1" >checking</td>
#                         <td id="T_a4e98_row11_col2" class="data row11 col2" >82</td>
#             </tr>
#             <tr>
#                                 <td id="T_a4e98_row12_col0" class="data row12 col0" >1</td>
#                         <td id="T_a4e98_row12_col1" class="data row12 col1" >checking</td>
#                         <td id="T_a4e98_row12_col2" class="data row12 col2" >87</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Highlight max/min values - standalone example

# %%
import pandas as pd
import numpy as np

np.random.seed(24)
df = pd.DataFrame({'A': np.linspace(1, 10, 10)})
df2 = pd.DataFrame(np.random.randn(10, 4), columns=list('BCDE'))

df = pd.concat([df, df2], axis=1)
df.iloc[0, 2] = np.nan

(df.style.apply(highlight_max, subset=['B', 'E'], color='red', axis=0)
         .apply(highlight_max, subset=['B', 'E'], type='background', color='yellow', axis=0))
# Out:
# <style  type="text/css" >
# #T_16384_row2_col4,#T_16384_row8_col1{
#             color:  red;
#             background-color:  yellow;
#         }</style><table id="T_16384_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_16384_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_16384_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_16384_row0_col1" class="data row0 col1" >1.329212</td>
#                         <td id="T_16384_row0_col2" class="data row0 col2" >nan</td>
#                         <td id="T_16384_row0_col3" class="data row0 col3" >-0.316280</td>
#                         <td id="T_16384_row0_col4" class="data row0 col4" >-0.990810</td>
#             </tr>
#             <tr>
#                         <th id="T_16384_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_16384_row1_col0" class="data row1 col0" >2.000000</td>
#                         <td id="T_16384_row1_col1" class="data row1 col1" >-1.070816</td>
#                         <td id="T_16384_row1_col2" class="data row1 col2" >-1.438713</td>
#                         <td id="T_16384_row1_col3" class="data row1 col3" >0.564417</td>
#                         <td id="T_16384_row1_col4" class="data row1 col4" >0.295722</td>
#             </tr>
#             <tr>
#                         <th id="T_16384_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_16384_row2_col0" class="data row2 col0" >3.000000</td>
#                         <td id="T_16384_row2_col1" class="data row2 col1" >-1.626404</td>
#                         <td id="T_16384_row2_col2" class="data row2 col2" >0.219565</td>
#                         <td id="T_16384_row2_col3" class="data row2 col3" >0.678805</td>
#                         <td id="T_16384_row2_col4" class="data row2 col4" >1.889273</td>
#             </tr>
#             <tr>
#                         <th id="T_16384_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_16384_row3_col0" class="data row3 col0" >4.000000</td>
#                         <td id="T_16384_row3_col1" class="data row3 col1" >0.961538</td>
#                         <td id="T_16384_row3_col2" class="data row3 col2" >0.104011</td>
#                         <td id="T_16384_row3_col3" class="data row3 col3" >-0.481165</td>
#                         <td id="T_16384_row3_col4" class="data row3 col4" >0.850229</td>
#             </tr>
#             <tr>
#                         <th id="T_16384_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_16384_row4_col0" class="data row4 col0" >5.000000</td>
#                         <td id="T_16384_row4_col1" class="data row4 col1" >1.453425</td>
#                         <td id="T_16384_row4_col2" class="data row4 col2" >1.057737</td>
#                         <td id="T_16384_row4_col3" class="data row4 col3" >0.165562</td>
#                         <td id="T_16384_row4_col4" class="data row4 col4" >0.515018</td>
#             </tr>
#             <tr>
#                         <th id="T_16384_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_16384_row5_col0" class="data row5 col0" >6.000000</td>
#                         <td id="T_16384_row5_col1" class="data row5 col1" >-1.336936</td>
#                         <td id="T_16384_row5_col2" class="data row5 col2" >0.562861</td>
#                         <td id="T_16384_row5_col3" class="data row5 col3" >1.392855</td>
#                         <td id="T_16384_row5_col4" class="data row5 col4" >-0.063328</td>
#             </tr>
#             <tr>
#                         <th id="T_16384_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_16384_row6_col0" class="data row6 col0" >7.000000</td>
#                         <td id="T_16384_row6_col1" class="data row6 col1" >0.121668</td>
#                         <td id="T_16384_row6_col2" class="data row6 col2" >1.207603</td>
#                         <td id="T_16384_row6_col3" class="data row6 col3" >-0.002040</td>
#                         <td id="T_16384_row6_col4" class="data row6 col4" >1.627796</td>
#             </tr>
#             <tr>
#                         <th id="T_16384_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_16384_row7_col0" class="data row7 col0" >8.000000</td>
#                         <td id="T_16384_row7_col1" class="data row7 col1" >0.354493</td>
#                         <td id="T_16384_row7_col2" class="data row7 col2" >1.037528</td>
#                         <td id="T_16384_row7_col3" class="data row7 col3" >-0.385684</td>
#                         <td id="T_16384_row7_col4" class="data row7 col4" >0.519818</td>
#             </tr>
#             <tr>
#                         <th id="T_16384_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_16384_row8_col0" class="data row8 col0" >9.000000</td>
#                         <td id="T_16384_row8_col1" class="data row8 col1" >1.686583</td>
#                         <td id="T_16384_row8_col2" class="data row8 col2" >-1.325963</td>
#                         <td id="T_16384_row8_col3" class="data row8 col3" >1.428984</td>
#                         <td id="T_16384_row8_col4" class="data row8 col4" >-2.089354</td>
#             </tr>
#             <tr>
#                         <th id="T_16384_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_16384_row9_col0" class="data row9 col0" >10.000000</td>
#                         <td id="T_16384_row9_col1" class="data row9 col1" >-0.129820</td>
#                         <td id="T_16384_row9_col2" class="data row9 col2" >0.631523</td>
#                         <td id="T_16384_row9_col3" class="data row9 col3" >-0.586538</td>
#                         <td id="T_16384_row9_col4" class="data row9 col4" >0.290720</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Format options

# %%
(merge_df[:10]
 .style

 .format({"account": "{:.0f}", "balance": "{:.0f}",
          "account2": "{:.4f}", "balance2": "{:.0f}"})
 .hide_index()
 .set_caption("This is a caption that is modified").set_table_styles([{
    'selector': 'caption',
    'props': [('color', 'blue'), ('font-size', '18px')
    ]
}])
)#.to_excel('outputs/test2.xlsx', index=False, freeze_panes=(1, 0), verbose=True)
# Out:
# <style  type="text/css" >
#     #T_d7bef_ caption {
#           color: blue;
#           font-size: 18px;
#     }</style><table id="T_d7bef_" ><caption>This is a caption that is modified</caption><thead>    <tr>        <th class="col_heading level0 col0" >account</th>        <th class="col_heading level0 col1" >type</th>        <th class="col_heading level0 col2" >balance</th>        <th class="col_heading level0 col3" >account2</th>        <th class="col_heading level0 col4" >type2</th>        <th class="col_heading level0 col5" >balance2</th>        <th class="col_heading level0 col6" >account2 is null</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_d7bef_row0_col0" class="data row0 col0" >13</td>
#                         <td id="T_d7bef_row0_col1" class="data row0 col1" >savings</td>
#                         <td id="T_d7bef_row0_col2" class="data row0 col2" >20</td>
#                         <td id="T_d7bef_row0_col3" class="data row0 col3" >13.0000</td>
#                         <td id="T_d7bef_row0_col4" class="data row0 col4" >checking</td>
#                         <td id="T_d7bef_row0_col5" class="data row0 col5" >54</td>
#                         <td id="T_d7bef_row0_col6" class="data row0 col6" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_d7bef_row1_col0" class="data row1 col0" >13</td>
#                         <td id="T_d7bef_row1_col1" class="data row1 col1" >savings</td>
#                         <td id="T_d7bef_row1_col2" class="data row1 col2" >20</td>
#                         <td id="T_d7bef_row1_col3" class="data row1 col3" >13.0000</td>
#                         <td id="T_d7bef_row1_col4" class="data row1 col4" >savings</td>
#                         <td id="T_d7bef_row1_col5" class="data row1 col5" >20</td>
#                         <td id="T_d7bef_row1_col6" class="data row1 col6" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_d7bef_row2_col0" class="data row2 col0" >12</td>
#                         <td id="T_d7bef_row2_col1" class="data row2 col1" >savings</td>
#                         <td id="T_d7bef_row2_col2" class="data row2 col2" >31</td>
#                         <td id="T_d7bef_row2_col3" class="data row2 col3" >12.0000</td>
#                         <td id="T_d7bef_row2_col4" class="data row2 col4" >savings</td>
#                         <td id="T_d7bef_row2_col5" class="data row2 col5" >33</td>
#                         <td id="T_d7bef_row2_col6" class="data row2 col6" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_d7bef_row3_col0" class="data row3 col0" >11</td>
#                         <td id="T_d7bef_row3_col1" class="data row3 col1" >savings</td>
#                         <td id="T_d7bef_row3_col2" class="data row3 col2" >16</td>
#                         <td id="T_d7bef_row3_col3" class="data row3 col3" >11.0000</td>
#                         <td id="T_d7bef_row3_col4" class="data row3 col4" >savings</td>
#                         <td id="T_d7bef_row3_col5" class="data row3 col5" >30</td>
#                         <td id="T_d7bef_row3_col6" class="data row3 col6" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_d7bef_row4_col0" class="data row4 col0" >10</td>
#                         <td id="T_d7bef_row4_col1" class="data row4 col1" >checking</td>
#                         <td id="T_d7bef_row4_col2" class="data row4 col2" >54</td>
#                         <td id="T_d7bef_row4_col3" class="data row4 col3" >0.0000</td>
#                         <td id="T_d7bef_row4_col4" class="data row4 col4" >0</td>
#                         <td id="T_d7bef_row4_col5" class="data row4 col5" >0</td>
#                         <td id="T_d7bef_row4_col6" class="data row4 col6" >True</td>
#             </tr>
#             <tr>
#                                 <td id="T_d7bef_row5_col0" class="data row5 col0" >9</td>
#                         <td id="T_d7bef_row5_col1" class="data row5 col1" >checking</td>
#                         <td id="T_d7bef_row5_col2" class="data row5 col2" >18</td>
#                         <td id="T_d7bef_row5_col3" class="data row5 col3" >9.0000</td>
#                         <td id="T_d7bef_row5_col4" class="data row5 col4" >checking</td>
#                         <td id="T_d7bef_row5_col5" class="data row5 col5" >18</td>
#                         <td id="T_d7bef_row5_col6" class="data row5 col6" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_d7bef_row6_col0" class="data row6 col0" >8</td>
#                         <td id="T_d7bef_row6_col1" class="data row6 col1" >checking</td>
#                         <td id="T_d7bef_row6_col2" class="data row6 col2" >33</td>
#                         <td id="T_d7bef_row6_col3" class="data row6 col3" >8.0000</td>
#                         <td id="T_d7bef_row6_col4" class="data row6 col4" >savings</td>
#                         <td id="T_d7bef_row6_col5" class="data row6 col5" >76</td>
#                         <td id="T_d7bef_row6_col6" class="data row6 col6" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_d7bef_row7_col0" class="data row7 col0" >7</td>
#                         <td id="T_d7bef_row7_col1" class="data row7 col1" >checking</td>
#                         <td id="T_d7bef_row7_col2" class="data row7 col2" >42</td>
#                         <td id="T_d7bef_row7_col3" class="data row7 col3" >7.0000</td>
#                         <td id="T_d7bef_row7_col4" class="data row7 col4" >checking</td>
#                         <td id="T_d7bef_row7_col5" class="data row7 col5" >27</td>
#                         <td id="T_d7bef_row7_col6" class="data row7 col6" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_d7bef_row8_col0" class="data row8 col0" >6</td>
#                         <td id="T_d7bef_row8_col1" class="data row8 col1" >checking</td>
#                         <td id="T_d7bef_row8_col2" class="data row8 col2" >27</td>
#                         <td id="T_d7bef_row8_col3" class="data row8 col3" >6.0000</td>
#                         <td id="T_d7bef_row8_col4" class="data row8 col4" >checking</td>
#                         <td id="T_d7bef_row8_col5" class="data row8 col5" >43</td>
#                         <td id="T_d7bef_row8_col6" class="data row8 col6" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_d7bef_row9_col0" class="data row9 col0" >5</td>
#                         <td id="T_d7bef_row9_col1" class="data row9 col1" >savings</td>
#                         <td id="T_d7bef_row9_col2" class="data row9 col2" >76</td>
#                         <td id="T_d7bef_row9_col3" class="data row9 col3" >5.0000</td>
#                         <td id="T_d7bef_row9_col4" class="data row9 col4" >checking</td>
#                         <td id="T_d7bef_row9_col5" class="data row9 col5" >33</td>
#                         <td id="T_d7bef_row9_col6" class="data row9 col6" >False</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### data bars

# %%
(merge_df
 .style
 .bar(subset=["account",], color='lightgreen')
 .bar(subset=["balance2",], color='lightblue')
 .format({"account": "{:.0f}", "balance": "{:.0f}",
          "account2": "{:.4f}", "balance2": "{:.0f}"})
 .hide_index()
 .highlight_null(null_color='blue')
 .highlight_max(color='green')
 .highlight_min(color='#cd4f39')
 .set_caption('this is a test')
)#.to_excel('outputs/test2.xlsx', index=False, freeze_panes=(1, 0), verbose=True)
# Out:
# <style  type="text/css" >
# #T_422af_row0_col0,#T_422af_row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 100.0%, transparent 100.0%);
#             background-color:  green;
#         }#T_422af_row0_col3,#T_422af_row1_col3,#T_422af_row13_col2{
#             background-color:  green;
#         }#T_422af_row0_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 62.1%, transparent 62.1%);
#         }#T_422af_row1_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 23.0%, transparent 23.0%);
#         }#T_422af_row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 91.7%, transparent 91.7%);
#         }#T_422af_row2_col5,#T_422af_row9_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 37.9%, transparent 37.9%);
#         }#T_422af_row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 83.3%, transparent 83.3%);
#         }#T_422af_row3_col2,#T_422af_row4_col3{
#             background-color:  #cd4f39;
#         }#T_422af_row3_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 34.5%, transparent 34.5%);
#         }#T_422af_row4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 75.0%, transparent 75.0%);
#         }#T_422af_row4_col5,#T_422af_row13_col0{
#             width:  10em;
#              height:  80%;
#             background-color:  #cd4f39;
#         }#T_422af_row5_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 66.7%, transparent 66.7%);
#         }#T_422af_row5_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 20.7%, transparent 20.7%);
#         }#T_422af_row6_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 58.3%, transparent 58.3%);
#         }#T_422af_row6_col5,#T_422af_row10_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 87.4%, transparent 87.4%);
#         }#T_422af_row7_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 50.0%, transparent 50.0%);
#         }#T_422af_row7_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 31.0%, transparent 31.0%);
#         }#T_422af_row8_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 41.7%, transparent 41.7%);
#         }#T_422af_row8_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 49.4%, transparent 49.4%);
#         }#T_422af_row9_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 33.3%, transparent 33.3%);
#         }#T_422af_row10_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 25.0%, transparent 25.0%);
#         }#T_422af_row11_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 16.7%, transparent 16.7%);
#         }#T_422af_row11_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 94.3%, transparent 94.3%);
#         }#T_422af_row12_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 8.3%, transparent 8.3%);
#         }#T_422af_row12_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 41.4%, transparent 41.4%);
#         }#T_422af_row13_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 100.0%, transparent 100.0%);
#             background-color:  green;
#         }</style><table id="T_422af_" ><caption>this is a test</caption><thead>    <tr>        <th class="col_heading level0 col0" >account</th>        <th class="col_heading level0 col1" >type</th>        <th class="col_heading level0 col2" >balance</th>        <th class="col_heading level0 col3" >account2</th>        <th class="col_heading level0 col4" >type2</th>        <th class="col_heading level0 col5" >balance2</th>        <th class="col_heading level0 col6" >account2 is null</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_422af_row0_col0" class="data row0 col0" >13</td>
#                         <td id="T_422af_row0_col1" class="data row0 col1" >savings</td>
#                         <td id="T_422af_row0_col2" class="data row0 col2" >20</td>
#                         <td id="T_422af_row0_col3" class="data row0 col3" >13.0000</td>
#                         <td id="T_422af_row0_col4" class="data row0 col4" >checking</td>
#                         <td id="T_422af_row0_col5" class="data row0 col5" >54</td>
#                         <td id="T_422af_row0_col6" class="data row0 col6" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_422af_row1_col0" class="data row1 col0" >13</td>
#                         <td id="T_422af_row1_col1" class="data row1 col1" >savings</td>
#                         <td id="T_422af_row1_col2" class="data row1 col2" >20</td>
#                         <td id="T_422af_row1_col3" class="data row1 col3" >13.0000</td>
#                         <td id="T_422af_row1_col4" class="data row1 col4" >savings</td>
#                         <td id="T_422af_row1_col5" class="data row1 col5" >20</td>
#                         <td id="T_422af_row1_col6" class="data row1 col6" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_422af_row2_col0" class="data row2 col0" >12</td>
#                         <td id="T_422af_row2_col1" class="data row2 col1" >savings</td>
#                         <td id="T_422af_row2_col2" class="data row2 col2" >31</td>
#                         <td id="T_422af_row2_col3" class="data row2 col3" >12.0000</td>
#                         <td id="T_422af_row2_col4" class="data row2 col4" >savings</td>
#                         <td id="T_422af_row2_col5" class="data row2 col5" >33</td>
#                         <td id="T_422af_row2_col6" class="data row2 col6" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_422af_row3_col0" class="data row3 col0" >11</td>
#                         <td id="T_422af_row3_col1" class="data row3 col1" >savings</td>
#                         <td id="T_422af_row3_col2" class="data row3 col2" >16</td>
#                         <td id="T_422af_row3_col3" class="data row3 col3" >11.0000</td>
#                         <td id="T_422af_row3_col4" class="data row3 col4" >savings</td>
#                         <td id="T_422af_row3_col5" class="data row3 col5" >30</td>
#                         <td id="T_422af_row3_col6" class="data row3 col6" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_422af_row4_col0" class="data row4 col0" >10</td>
#                         <td id="T_422af_row4_col1" class="data row4 col1" >checking</td>
#                         <td id="T_422af_row4_col2" class="data row4 col2" >54</td>
#                         <td id="T_422af_row4_col3" class="data row4 col3" >0.0000</td>
#                         <td id="T_422af_row4_col4" class="data row4 col4" >0</td>
#                         <td id="T_422af_row4_col5" class="data row4 col5" >0</td>
#                         <td id="T_422af_row4_col6" cla

# %% [markdown]
# ### highlight rows (including null values)

# %%
import pandas as pd
import numpy as np

# np.random.seed(24)
df = pd.DataFrame({'A': np.linspace(1, 10, 10)})
df2 = pd.DataFrame(6+np.random.randn(8, 4), columns=list('BCDE'))

df = pd.concat([df, df2], axis=1)
df.iloc[0, 2] = np.nan

# %%
(df.style.hide_index()
         .apply(highlight_rows, column='B', operator='>=', criteria=5, axis=1)
         .apply(highlight_rows, column='B', operator='>=', criteria=5, axis=1,
                type='background', color='yellow')   
)
# Out:
# <style  type="text/css" >
# #T_12431_row0_col0,#T_12431_row0_col1,#T_12431_row0_col2,#T_12431_row0_col3,#T_12431_row0_col4,#T_12431_row1_col0,#T_12431_row1_col1,#T_12431_row1_col2,#T_12431_row1_col3,#T_12431_row1_col4,#T_12431_row3_col0,#T_12431_row3_col1,#T_12431_row3_col2,#T_12431_row3_col3,#T_12431_row3_col4,#T_12431_row4_col0,#T_12431_row4_col1,#T_12431_row4_col2,#T_12431_row4_col3,#T_12431_row4_col4,#T_12431_row5_col0,#T_12431_row5_col1,#T_12431_row5_col2,#T_12431_row5_col3,#T_12431_row5_col4,#T_12431_row6_col0,#T_12431_row6_col1,#T_12431_row6_col2,#T_12431_row6_col3,#T_12431_row6_col4{
#             color:  blue;
#             background-color:  yellow;
#         }</style><table id="T_12431_" ><thead>    <tr>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_12431_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_12431_row0_col1" class="data row0 col1" >7.264103</td>
#                         <td id="T_12431_row0_col2" class="data row0 col2" >nan</td>
#                         <td id="T_12431_row0_col3" class="data row0 col3" >4.029712</td>
#                         <td id="T_12431_row0_col4" class="data row0 col4" >6.803906</td>
#             </tr>
#             <tr>
#                                 <td id="T_12431_row1_col0" class="data row1 col0" >2.000000</td>
#                         <td id="T_12431_row1_col1" class="data row1 col1" >7.030550</td>
#                         <td id="T_12431_row1_col2" class="data row1 col2" >6.118098</td>
#                         <td id="T_12431_row1_col3" class="data row1 col3" >5.978147</td>
#                         <td id="T_12431_row1_col4" class="data row1 col4" >6.046841</td>
#             </tr>
#             <tr>
#                                 <td id="T_12431_row2_col0" class="data row2 col0" >3.000000</td>
#                         <td id="T_12431_row2_col1" class="data row2 col1" >4.371247</td>
#                         <td id="T_12431_row2_col2" class="data row2 col2" >5.607639</td>
#                         <td id="T_12431_row2_col3" class="data row2 col3" >7.700973</td>
#                         <td id="T_12431_row2_col4" class="data row2 col4" >7.061330</td>
#             </tr>
#             <tr>
#                                 <td id="T_12431_row3_col0" class="data row3 col0" >4.000000</td>
#                         <td id="T_12431_row3_col1" class="data row3 col1" >6.695804</td>
#                         <td id="T_12431_row3_col2" class="data row3 col2" >5.564011</td>
#                         <td id="T_12431_row3_col3" class="data row3 col3" >5.667058</td>
#                         <td id="T_12431_row3_col4" class="data row3 col4" >6.602135</td>
#             </tr>
#             <tr>
#                                 <td id="T_12431_row4_col0" class="data row4 col0" >5.000000</td>
#                         <td id="T_12431_row4_col1" class="data row4 col1" >6.108789</td>
#                         <td id="T_12431_row4_col2" class="data row4 col2" >6.036767</td>
#                         <td id="T_12431_row4_col3" class="data row4 col3" >5.461037</td>
#                         <td id="T_12431_row4_col4" class="data row4 col4" >6.499178</td>
#             </tr>
#             <tr>
#                                 <td id="T_12431_row5_col0" class="data row5 col0" >6.000000</td>
#                         <td id="T_12431_row5_col1" class="data row5 col1" >5.288048</td>
#                         <td id="T_12431_row5_col2" class="data row5 col2" >5.762999</td>
#                         <td id="T_12431_row5_col3" class="data row5 col3" >6.857119</td>
#                         <td id="T_12431_row5_col4" class="data row5 col4" >4.117648</td>
#             </tr>
#             <tr>
#                                 <td id="T_12431_row6_col0" class="data row6 col0" >7.000000</td>
#                         <td id="T_12431_row6_col1" class="data row6 col1" >6.420705</td>
#                         <td id="T_12431_row6_col2" class="data row6 col2" >4.930825</td>
#                         <td id="T_12431_row6_col3" class="data row6 col3" >3.423141</td>
#                         <td id="T_12431_row6_col4" class="data row6 col4" >4.775077</td>
#             </tr>
#             <tr>
#                                 <td id="T_12431_row7_col0" class="data row7 col0" >8.000000</td>
#                         <td id="T_12431_row7_col1" class="data row7 col1" >4.843248</td>
#                         <td id="T_12431_row7_col2" class="data row7 col2" >6.931304</td>
#                         <td id="T_12431_row7_col3" class="data row7 col3" >6.984257</td>
#                         <td id="T_12431_row7_col4" class="data row7 col4" >8.226159</td>
#             </tr>
#             <tr>
#                                 <td id="T_12431_row8_col0" class="data row8 col0" >9.000000</td>
#                         <td id="T_12431_row8_col1" class="data row8 col1" >nan</td>
#                         <td id="T_12431_row8_col2" class="data row8 col2" >nan</td>
#                         <td id="T_12431_row8_col3" class="data row8 col3" >nan</td>
#                         <td id="T_12431_row8_col4" class="data row8 col4" >nan</td>
#             </tr>
#             <tr>
#                                 <td id="T_12431_row9_col0" class="data row9 col0" >10.000000</td>
#                         <td id="T_12431_row9_col1" class="data row9 col1" >nan</td>
#                         <td id="T_12431_row9_col2" class="data row9 col2" >nan</td>
#                         <td id="T_12431_row9_col3" class="data row9 col3" >nan</td>
#                         <td id="T_12431_row9_col4" class="data row9 col4" >nan</td>
#             </tr>
#     </tbody></table>

# %%
# %run style_utils2.py

(df.style.hide_index()
         .highlight_null(null_color='yellow')
         .apply(highlight_null_rows, column='B', operator='=', axis=1, color='yellow')
         .apply(highlight_null_rows, column='B', operator='=', axis=1,
                type='background', color='blue')   
)
# Out:
# File `'style_utils2.py'` not found.
# <style  type="text/css" >
# #T_ab55b_row0_col2{
#             background-color:  yellow;
#         }#T_ab55b_row8_col0,#T_ab55b_row9_col0{
#             color:  yellow;
#             background-color:  blue;
#         }#T_ab55b_row8_col1,#T_ab55b_row8_col2,#T_ab55b_row8_col3,#T_ab55b_row8_col4,#T_ab55b_row9_col1,#T_ab55b_row9_col2,#T_ab55b_row9_col3,#T_ab55b_row9_col4{
#             background-color:  yellow;
#             color:  yellow;
#             background-color:  blue;
#         }</style><table id="T_ab55b_" ><thead>    <tr>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_ab55b_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_ab55b_row0_col1" class="data row0 col1" >7.264103</td>
#                         <td id="T_ab55b_row0_col2" class="data row0 col2" >nan</td>
#                         <td id="T_ab55b_row0_col3" class="data row0 col3" >4.029712</td>
#                         <td id="T_ab55b_row0_col4" class="data row0 col4" >6.803906</td>
#             </tr>
#             <tr>
#                                 <td id="T_ab55b_row1_col0" class="data row1 col0" >2.000000</td>
#                         <td id="T_ab55b_row1_col1" class="data row1 col1" >7.030550</td>
#                         <td id="T_ab55b_row1_col2" class="data row1 col2" >6.118098</td>
#                         <td id="T_ab55b_row1_col3" class="data row1 col3" >5.978147</td>
#                         <td id="T_ab55b_row1_col4" class="data row1 col4" >6.046841</td>
#             </tr>
#             <tr>
#                                 <td id="T_ab55b_row2_col0" class="data row2 col0" >3.000000</td>
#                         <td id="T_ab55b_row2_col1" class="data row2 col1" >4.371247</td>
#                         <td id="T_ab55b_row2_col2" class="data row2 col2" >5.607639</td>
#                         <td id="T_ab55b_row2_col3" class="data row2 col3" >7.700973</td>
#                         <td id="T_ab55b_row2_col4" class="data row2 col4" >7.061330</td>
#             </tr>
#             <tr>
#                                 <td id="T_ab55b_row3_col0" class="data row3 col0" >4.000000</td>
#                         <td id="T_ab55b_row3_col1" class="data row3 col1" >6.695804</td>
#                         <td id="T_ab55b_row3_col2" class="data row3 col2" >5.564011</td>
#                         <td id="T_ab55b_row3_col3" class="data row3 col3" >5.667058</td>
#                         <td id="T_ab55b_row3_col4" class="data row3 col4" >6.602135</td>
#             </tr>
#             <tr>
#                                 <td id="T_ab55b_row4_col0" class="data row4 col0" >5.000000</td>
#                         <td id="T_ab55b_row4_col1" class="data row4 col1" >6.108789</td>
#                         <td id="T_ab55b_row4_col2" class="data row4 col2" >6.036767</td>
#                         <td id="T_ab55b_row4_col3" class="data row4 col3" >5.461037</td>
#                         <td id="T_ab55b_row4_col4" class="data row4 col4" >6.499178</td>
#             </tr>
#             <tr>
#                                 <td id="T_ab55b_row5_col0" class="data row5 col0" >6.000000</td>
#                         <td id="T_ab55b_row5_col1" class="data row5 col1" >5.288048</td>
#                         <td id="T_ab55b_row5_col2" class="data row5 col2" >5.762999</td>
#                         <td id="T_ab55b_row5_col3" class="data row5 col3" >6.857119</td>
#                         <td id="T_ab55b_row5_col4" class="data row5 col4" >4.117648</td>
#             </tr>
#             <tr>
#                                 <td id="T_ab55b_row6_col0" class="data row6 col0" >7.000000</td>
#                         <td id="T_ab55b_row6_col1" class="data row6 col1" >6.420705</td>
#                         <td id="T_ab55b_row6_col2" class="data row6 col2" >4.930825</td>
#                         <td id="T_ab55b_row6_col3" class="data row6 col3" >3.423141</td>
#                         <td id="T_ab55b_row6_col4" class="data row6 col4" >4.775077</td>
#             </tr>
#             <tr>
#                                 <td id="T_ab55b_row7_col0" class="data row7 col0" >8.000000</td>
#                         <td id="T_ab55b_row7_col1" class="data row7 col1" >4.843248</td>
#                         <td id="T_ab55b_row7_col2" class="data row7 col2" >6.931304</td>
#                         <td id="T_ab55b_row7_col3" class="data row7 col3" >6.984257</td>
#                         <td id="T_ab55b_row7_col4" class="data row7 col4" >8.226159</td>
#             </tr>
#             <tr>
#                                 <td id="T_ab55b_row8_col0" class="data row8 col0" >9.000000</td>
#                         <td id="T_ab55b_row8_col1" class="data row8 col1" >nan</td>
#                         <td id="T_ab55b_row8_col2" class="data row8 col2" >nan</td>
#                         <td id="T_ab55b_row8_col3" class="data row8 col3" >nan</td>
#                         <td id="T_ab55b_row8_col4" class="data row8 col4" >nan</td>
#             </tr>
#             <tr>
#                                 <td id="T_ab55b_row9_col0" class="data row9 col0" >10.000000</td>
#                         <td id="T_ab55b_row9_col1" class="data row9 col1" >nan</td>
#                         <td id="T_ab55b_row9_col2" class="data row9 col2" >nan</td>
#                         <td id="T_ab55b_row9_col3" class="data row9 col3" >nan</td>
#                         <td id="T_ab55b_row9_col4" class="data row9 col4" >nan</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## DataFrame formats

# %% [markdown]
# ### AS/400 Style

# %%
as400_style = {'background-color': 'black', 'color': 'lightgreen', 'font-size': '140%'}

xl_output = (head(merge_df, 8).style.set_properties(**as400_style)
                  .hide_index()
                  .apply(highlight_max, subset=['account2', 'balance', 'account2 is null'],
                         color='yellow'))
xl_output
# Out:
# 14 rows, 7 columns
# <style  type="text/css" >
# #T_171a8_row0_col0,#T_171a8_row0_col1,#T_171a8_row0_col2,#T_171a8_row0_col4,#T_171a8_row0_col5,#T_171a8_row0_col6,#T_171a8_row1_col0,#T_171a8_row1_col1,#T_171a8_row1_col2,#T_171a8_row1_col4,#T_171a8_row1_col5,#T_171a8_row1_col6,#T_171a8_row2_col0,#T_171a8_row2_col1,#T_171a8_row2_col2,#T_171a8_row2_col3,#T_171a8_row2_col4,#T_171a8_row2_col5,#T_171a8_row2_col6,#T_171a8_row3_col0,#T_171a8_row3_col1,#T_171a8_row3_col2,#T_171a8_row3_col3,#T_171a8_row3_col4,#T_171a8_row3_col5,#T_171a8_row3_col6,#T_171a8_row4_col0,#T_171a8_row4_col1,#T_171a8_row4_col3,#T_171a8_row4_col4,#T_171a8_row4_col5,#T_171a8_row5_col0,#T_171a8_row5_col1,#T_171a8_row5_col2,#T_171a8_row5_col3,#T_171a8_row5_col4,#T_171a8_row5_col5,#T_171a8_row5_col6,#T_171a8_row6_col0,#T_171a8_row6_col1,#T_171a8_row6_col2,#T_171a8_row6_col3,#T_171a8_row6_col4,#T_171a8_row6_col5,#T_171a8_row6_col6,#T_171a8_row7_col0,#T_171a8_row7_col1,#T_171a8_row7_col2,#T_171a8_row7_col3,#T_171a8_row7_col4,#T_171a8_row7_col5,#T_171a8_row7_col6{
#             background-color:  black;
#             color:  lightgreen;
#             font-size:  140%;
#         }#T_171a8_row0_col3,#T_171a8_row1_col3,#T_171a8_row4_col2,#T_171a8_row4_col6{
#             background-color:  black;
#             color:  lightgreen;
#             font-size:  140%;
#             color:  yellow;
#         }</style><table id="T_171a8_" ><thead>    <tr>        <th class="col_heading level0 col0" >account</th>        <th class="col_heading level0 col1" >type</th>        <th class="col_heading level0 col2" >balance</th>        <th class="col_heading level0 col3" >account2</th>        <th class="col_heading level0 col4" >type2</th>        <th class="col_heading level0 col5" >balance2</th>        <th class="col_heading level0 col6" >account2 is null</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_171a8_row0_col0" class="data row0 col0" >13</td>
#                         <td id="T_171a8_row0_col1" class="data row0 col1" >savings</td>
#                         <td id="T_171a8_row0_col2" class="data row0 col2" >20</td>
#                         <td id="T_171a8_row0_col3" class="data row0 col3" >13</td>
#                         <td id="T_171a8_row0_col4" class="data row0 col4" >checking</td>
#                         <td id="T_171a8_row0_col5" class="data row0 col5" >54</td>
#                         <td id="T_171a8_row0_col6" class="data row0 col6" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_171a8_row1_col0" class="data row1 col0" >13</td>
#                         <td id="T_171a8_row1_col1" class="data row1 col1" >savings</td>
#                         <td id="T_171a8_row1_col2" class="data row1 col2" >20</td>
#                         <td id="T_171a8_row1_col3" class="data row1 col3" >13</td>
#                         <td id="T_171a8_row1_col4" class="data row1 col4" >savings</td>
#                         <td id="T_171a8_row1_col5" class="data row1 col5" >20</td>
#                         <td id="T_171a8_row1_col6" class="data row1 col6" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_171a8_row2_col0" class="data row2 col0" >12</td>
#                         <td id="T_171a8_row2_col1" class="data row2 col1" >savings</td>
#                         <td id="T_171a8_row2_col2" class="data row2 col2" >31</td>
#                         <td id="T_171a8_row2_col3" class="data row2 col3" >12</td>
#                         <td id="T_171a8_row2_col4" class="data row2 col4" >savings</td>
#                         <td id="T_171a8_row2_col5" class="data row2 col5" >33</td>
#                         <td id="T_171a8_row2_col6" class="data row2 col6" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_171a8_row3_col0" class="data row3 col0" >11</td>
#                         <td id="T_171a8_row3_col1" class="data row3 col1" >savings</td>
#                         <td id="T_171a8_row3_col2" class="data row3 col2" >16</td>
#                         <td id="T_171a8_row3_col3" class="data row3 col3" >11</td>
#                         <td id="T_171a8_row3_col4" class="data row3 col4" >savings</td>
#                         <td id="T_171a8_row3_col5" class="data row3 col5" >30</td>
#                         <td id="T_171a8_row3_col6" class="data row3 col6" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_171a8_row4_col0" class="data row4 col0" >10</td>
#                         <td id="T_171a8_row4_col1" class="data row4 col1" >checking</td>
#                         <td id="T_171a8_row4_col2" class="data row4 col2" >54</td>
#                         <td id="T_171a8_row4_col3" class="data row4 col3" >0</td>
#                         <td id="T_171a8_row4_col4" class="data row4 col4" >0</td>
#                         <td id="T_171a8_row4_col5" class="data row4 col5" >0</td>
#                         <td id="T_171a8_row4_col6" class="data row4 col6" >True</td>
#             </tr>
#             <tr>
#                                 <td id="T_171a8_row5_col0" class="data row5 col0" >9</td>
#                         <td id="T_171a8_row5_col1" class="data row5 col1" >checking</td>
#                         <td id="T_171a8_row5_col2" class="data row5 col2" >18</td>
#                         <td id="T_171a8_row5_col3" class="data row5 col3" >9</td>
#                         <td id="T_171a8_row5_col4" class="data row5 col4" >checking</td>
#                         <td id="T_171a8_row5_col5" class="data row5 col5" >18</td>
#                         <td id="T_171a8_row5_col6" class="data row5 col6" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_171a8_row6_col0" class="data row6 col0" >8</td>
#                         <td id="T_171a8_row6_col1" class="data row6 col1" >checking</td>
#                         <td id="T_171a8_row6_col2" class="data row6 col2" >33</td>
#                         <td id="T_171a8_row6_col3" class="data row6 col3" >8</td>
#                         <td id="T_171a8_row6_col4" class="data row6 col4" >savings</td>
#                         <td id="T_171a8_row6_col5" class="data row6 col5" >76</td>
#                         <td id="T_171a8_row6_col6" class="data row6 col6" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_171a8_row7_col0" class="data row7 col0" >7</td>
#                         <td id="T_171a8_row7_col1" class="data row7 col1" >checking</td>
#                         <td id="T_171a8_row7_col2" class="data row7 col2" >42</td>
#                         <td id="T_171a8_row7_col3" class="data row7 col3" >7</td>
#                         <td id="T_171a8_row7_col4" class="data row7 col4" >checking</td>
#                         <td id="T_171a8_row7_col5" class="data row7 col5" >27</td>
#                         <td id="T_171a8_row7_col6" class="data row7 col6" >False</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Alternative style

# %%
xl_output = (head(merge_df, 8).style.set_table_styles(get_default_style())
             .apply(highlight_min, subset='balance', color='yellow')
             .apply(highlight_min, subset='balance', type='background', color='blue')
             .apply(highlight_max, subset='balance', color='yellow')
             .apply(highlight_max, subset='balance', type='background', color='green')
#                   .hide_index()
            )
xl_output
# Out:
# 14 rows, 7 columns
# <style  type="text/css" >
#     #T_27819_ * {
#           border: 1px solid #9EB6CE;
#           border-width: 1px 1px 1px 1px;
#           font-size: 15px;
#           font-weight: 200;
#           table-layout: auto;
#           border-spacing: 0px;
#           border-collapse: collapse;
#     }    #T_27819_ tbody tr:hover td {
#           background-color: #DCDCDC !important;
#           color: #000;
#     }    #T_27819_ th {
#           background-color: #E4ECF7;
#           font-weight: 600;
#           font-size: 15px;
#           border: 1px solid #9EB6CE;
#           border-width: 0px 1px 1px 0px;
#     }    #T_27819_ td {
#           border: 0px;
#           font-size: 14px;
#           padding: 2px 5px 2px 5px;
#           border: 1px solid #9EB6CE;
#           border-width: 1px 1px 1px 1px;
#     }#T_27819_row3_col2{
#             color:  yellow;
#             background-color:  blue;
#         }#T_27819_row4_col2{
#             color:  yellow;
#             background-color:  green;
#         }</style><table id="T_27819_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >account</th>        <th class="col_heading level0 col1" >type</th>        <th class="col_heading level0 col2" >balance</th>        <th class="col_heading level0 col3" >account2</th>        <th class="col_heading level0 col4" >type2</th>        <th class="col_heading level0 col5" >balance2</th>        <th class="col_heading level0 col6" >account2 is null</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_27819_level0_row0" class="row_heading level0 row0" >12</th>
#                         <td id="T_27819_row0_col0" class="data row0 col0" >13</td>
#                         <td id="T_27819_row0_col1" class="data row0 col1" >savings</td>
#                         <td id="T_27819_row0_col2" class="data row0 col2" >20</td>
#                         <td id="T_27819_row0_col3" class="data row0 col3" >13</td>
#                         <td id="T_27819_row0_col4" class="data row0 col4" >checking</td>
#                         <td id="T_27819_row0_col5" class="data row0 col5" >54</td>
#                         <td id="T_27819_row0_col6" class="data row0 col6" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_27819_level0_row1" class="row_heading level0 row1" >13</th>
#                         <td id="T_27819_row1_col0" class="data row1 col0" >13</td>
#                         <td id="T_27819_row1_col1" class="data row1 col1" >savings</td>
#                         <td id="T_27819_row1_col2" class="data row1 col2" >20</td>
#                         <td id="T_27819_row1_col3" class="data row1 col3" >13</td>
#                         <td id="T_27819_row1_col4" class="data row1 col4" >savings</td>
#                         <td id="T_27819_row1_col5" class="data row1 col5" >20</td>
#                         <td id="T_27819_row1_col6" class="data row1 col6" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_27819_level0_row2" class="row_heading level0 row2" >11</th>
#                         <td id="T_27819_row2_col0" class="data row2 col0" >12</td>
#                         <td id="T_27819_row2_col1" class="data row2 col1" >savings</td>
#                         <td id="T_27819_row2_col2" class="data row2 col2" >31</td>
#                         <td id="T_27819_row2_col3" class="data row2 col3" >12</td>
#                         <td id="T_27819_row2_col4" class="data row2 col4" >savings</td>
#                         <td id="T_27819_row2_col5" class="data row2 col5" >33</td>
#                         <td id="T_27819_row2_col6" class="data row2 col6" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_27819_level0_row3" class="row_heading level0 row3" >10</th>
#                         <td id="T_27819_row3_col0" class="data row3 col0" >11</td>
#                         <td id="T_27819_row3_col1" class="data row3 col1" >savings</td>
#                         <td id="T_27819_row3_col2" class="data row3 col2" >16</td>
#                         <td id="T_27819_row3_col3" class="data row3 col3" >11</td>
#                         <td id="T_27819_row3_col4" class="data row3 col4" >savings</td>
#                         <td id="T_27819_row3_col5" class="data row3 col5" >30</td>
#                         <td id="T_27819_row3_col6" class="data row3 col6" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_27819_level0_row4" class="row_heading level0 row4" >9</th>
#                         <td id="T_27819_row4_col0" class="data row4 col0" >10</td>
#                         <td id="T_27819_row4_col1" class="data row4 col1" >checking</td>
#                         <td id="T_27819_row4_col2" class="data row4 col2" >54</td>
#                         <td id="T_27819_row4_col3" class="data row4 col3" >0</td>
#                         <td id="T_27819_row4_col4" class="data row4 col4" >0</td>
#                         <td id="T_27819_row4_col5" class="data row4 col5" >0</td>
#                         <td id="T_27819_row4_col6" class="data row4 col6" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_27819_level0_row5" class="row_heading level0 row5" >8</th>
#                         <td id="T_27819_row5_col0" class="data row5 col0" >9</td>
#                         <td id="T_27819_row5_col1" class="data row5 col1" >checking</td>
#                         <td id="T_27819_row5_col2" class="data row5 col2" >18</td>
#                         <td id="T_27819_row5_col3" class="data row5 col3" >9</td>
#                         <td id="T_27819_row5_col4" class="data row5 col4" >checking</td>
#                         <td id="T_27819_row5_col5" class="data row5 col5" >18</td>
#                         <td id="T_27819_row5_col6" class="data row5 col6" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_27819_level0_row6" class="row_heading level0 row6" >7</th>
#                         <td id="T_27819_row6_col0" class="data row6 col0" >8</td>
#                         <td id="T_27819_row6_col1" class="data row6 col1" >checking</td>
#                         <td id="T_27819_row6_col2" class="data row6 col2" >33</td>
#                         <td id="T_27819_row6_col3" class="data row6 col3" >8</td>
#                         <td id="T_27819_row6_col4" class="data row6 col4" >savings</td>
#                         <td id="T_27819_row6_col5" class="data row6 col5" >76</td>
#                         <td id="T_27819_row6_col6" class="data row6 col6" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_27819_level0_row7" class="row_heading level0 row7" >6</th>
#                         <td id="T_27819_row7_col0" class="data row7 col0" >7</td>
#                         <td id="T_27819_row7_col1" class="data row7 col1" >checking</td>
#                         <td id="T_27819_row7_col2" class="data row7 col2" >42</td>
#                         <td id="T_27819_row7_col3" class="data row7 col3" >7</td>
#                         <td id="T_27819_row7_col4" class="data row7 col4" >checking</td>
#                         <td id="T_27819_row7_col5" class="data row7 col5" >27</td>
#                         <td id="T_27819_row7_col6" class="data row7 col6" >False</td>
#             </tr>
#     </tbody></table>

# %%
xx = df.groupby(['A', 'B','C']).agg(Total=pd.NamedAgg('D', 'sum'))
(head(xx, 8).style.set_table_styles(get_default_style()))
# Out:
# 7 rows, 1 columns
# <style  type="text/css" >
#     #T_e3935_ * {
#           border: 1px solid #9EB6CE;
#           border-width: 1px 1px 1px 1px;
#           font-size: 15px;
#           font-weight: 200;
#           table-layout: auto;
#           border-spacing: 0px;
#           border-collapse: collapse;
#     }    #T_e3935_ tbody tr:hover td {
#           background-color: #DCDCDC !important;
#           color: #000;
#     }    #T_e3935_ th {
#           background-color: #E4ECF7;
#           font-weight: 600;
#           font-size: 15px;
#           border: 1px solid #9EB6CE;
#           border-width: 0px 1px 1px 0px;
#     }    #T_e3935_ td {
#           border: 0px;
#           font-size: 14px;
#           padding: 2px 5px 2px 5px;
#           border: 1px solid #9EB6CE;
#           border-width: 1px 1px 1px 1px;
#     }</style><table id="T_e3935_" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total</th>    </tr>    <tr>        <th class="index_name level0" >A</th>        <th class="index_name level1" >B</th>        <th class="index_name level2" >C</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e3935_level0_row0" class="row_heading level0 row0" >2.0</th>
#                         <th id="T_e3935_level1_row0" class="row_heading level1 row0" >7.030550333953391</th>
#                         <th id="T_e3935_level2_row0" class="row_heading level2 row0" >6.118097935763157</th>
#                         <td id="T_e3935_row0_col0" class="data row0 col0" >5.978147</td>
#             </tr>
#             <tr>
#                         <th id="T_e3935_level0_row1" class="row_heading level0 row1" >3.0</th>
#                         <th id="T_e3935_level1_row1" class="row_heading level1 row1" >4.371247140873944</th>
#                         <th id="T_e3935_level2_row1" class="row_heading level2 row1" >5.607639409516747</th>
#                         <td id="T_e3935_row1_col0" class="data row1 col0" >7.700973</td>
#             </tr>
#             <tr>
#                         <th id="T_e3935_level0_row2" class="row_heading level0 row2" >4.0</th>
#                         <th id="T_e3935_level1_row2" class="row_heading level1 row2" >6.6958035738954935</th>
#                         <th id="T_e3935_level2_row2" class="row_heading level2 row2" >5.564011429755853</th>
#                         <td id="T_e3935_row2_col0" class="data row2 col0" >5.667058</td>
#             </tr>
#             <tr>
#                         <th id="T_e3935_level0_row3" class="row_heading level0 row3" >5.0</th>
#                         <th id="T_e3935_level1_row3" class="row_heading level1 row3" >6.108788958914832</th>
#                         <th id="T_e3935_level2_row3" class="row_heading level2 row3" >6.036766928625714</th>
#                         <td id="T_e3935_row3_col0" class="data row3 col0" >5.461037</td>
#             </tr>
#             <tr>
#                         <th id="T_e3935_level0_row4" class="row_heading level0 row4" >6.0</th>
#                         <th id="T_e3935_level1_row4" class="row_heading level1 row4" >5.288048243042802</th>
#                         <th id="T_e3935_level2_row4" class="row_heading level2 row4" >5.76299903072288</th>
#                         <td id="T_e3935_row4_col0" class="data row4 col0" >6.857119</td>
#             </tr>
#             <tr>
#                         <th id="T_e3935_level0_row5" class="row_heading level0 row5" >7.0</th>
#                         <th id="T_e3935_level1_row5" class="row_heading level1 row5" >6.420705086190522</th>
#                         <th id="T_e3935_level2_row5" class="row_heading level2 row5" >4.930824663172313</th>
#                         <td id="T_e3935_row5_col0" class="data row5 col0" >3.423141</td>
#             </tr>
#             <tr>
#                         <th id="T_e3935_level0_row6" class="row_heading level0 row6" >8.0</th>
#                         <th id="T_e3935_level1_row6" class="row_heading level1 row6" >4.843248140139934</th>
#                         <th id="T_e3935_level2_row6" class="row_heading level2 row6" >6.931304270876204</th>
#                         <td id="T_e3935_row6_col0" class="data row6 col0" >6.984257</td>
#             </tr>
#     </tbody></table>

# %%
xl_output.to_excel('outputs/test.xlsx', index=False, engine='openpyxl')

# %%
head(df)
# Out:
# 10 rows, 5 columns
#      A         B         C         D         E
# 0  1.0  7.264103       NaN  4.029712  6.803906
# 1  2.0  7.030550  6.118098  5.978147  6.046841
# 2  3.0  4.371247  5.607639  7.700973  7.061330
# 3  4.0  6.695804  5.564011  5.667058  6.602135
